# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv

response = req.get('https://www.sigma-computer.com/search?search=laptop&submit_search=&route=product%2Fsearch')

soup = bs(response.text, 'html.parser')

desc = soup.find_all('div', attrs={'class': 'product-layout col-lg-15 col-md-4 col-sm-6 col-xs-12'})


url_link= []
for i in range(len(desc)):
    url_link.append( 'https://www.sigma-computer.com/' +desc[i].find('a')['href'])

title= []
for i in range(len(desc)):
    title.append( desc[i].find('a')['title'])


price_new= []
for i in range(len(desc)):
    price_new.append( desc[i].find('span', attrs={'class': 'price-new'}).text)


price_old= []
for i in range(len(desc)):
    price_old.append( desc[i].find('span', attrs={'class': 'price-old'}).text)

descriptions = soup.find_all('div', {'class' :'description'})
strong = []
for i in range(len(descriptions)):
    strong_tag = descriptions[i].find('strong')
    if strong_tag:  
        strong.append(strong_tag.text)
    else:
        strong.append(None)

# %%
descriptions = soup.find_all('div', {'class' :'description'})

# %%
strong = []
for i in range(len(descriptions)):
    strong_tag = descriptions[i].find('strong')
    if strong_tag:  
        strong.append(strong_tag.text)
    else:
        strong.append(None)

# %%
strong
# Out:
# ['ضمــــــان سنــــــة',
#  'ضمــــــــان سنـــــــــة',
#  'ضمــــــــان سنـــــــــــة',
#  None,
#  'ضمــــــان سنــــة',
#  'ضمــــــان سنــــــة',
#  'ضمـــــــان سنتـــــين وكــــــيل',
#  'ضمـــــــان سنتـــــين وكــــــيل',
#  'ضمــــــان ثلاث سنــــوات',
#  'Technical Specifications:',
#  'MSI Thin 15 B13VE',
#  'ضمـــــــان سنتـــــين وكــــــيل',
#  'ضمــــــان سنــــة',
#  'JSAUX 8K@60Hz HDMI Cable - Premium Ultra-High-Definition Experience',
#  'Sigma Laptop Backpack for School and Travel (Red)',
#  'Sigma Laptop Backpack for School and Travel (Purple)',
#  'Sigma Laptop Backpack for School and Travel (Navy Blue)',
#  'Sigma Laptop Backpack for School and Travel (Gray)',
#  'Sigma Laptop Backpack for School and Travel (Blue)',
#  'Sigma Laptop Backpack',
#  'High R/W Speed (SATA Interface):',
#  'Highlights:',
#  'ضمــــان ســــنة',
#  'ضمــــان سنتيــــن',
#  'ضمــــان سنتيــــن',
#  'Acer Nitro V Gaming Laptop (ANV15-51-532J)',
#  'ضمــــــان سنــــــة',
#  'Lexar SL500M 1TB External SSD',
#  'Lexar SL500M 1TB External SSD',
#  'Type',
#  'Lexar 2TB Professional NM800 PRO SSD with Heatsink - Key Specs:',
#  'Capacity',
#  'ضمــــــان سنــــة',
#  'ضمــــــان سنــــة',
#  'OS',
#  'ضمــــــان سنــــــة',
#  'ضمــــــــــان سنـــــــــة',
#  'Key Features:',
#  'ضمـــــــــان سنـــــــــــة',
#  'ضمـــــــان سنـــــة',
#  None,
#  'PNY CS2130 2TB M.2 PCIe NVMe Gen3 x4 Internal Solid State Drive',
#  None,
#  'ضمـــــــان ثلاث سنــــوات',
#  'ضمــــــان سنــــة',
#  'Asus ROG Strix G17 G713PV-HX019W',
#  'ضمــــان ثلاث سنــــوات',
#  None,
#  'Processor',
#  'ضمـــــــان سنـــــة',
#  'Lexar® JumpDrive® Dual Drive D400',
#  'Samsung DDR5 SODIMM 16GB 4800MHz',
#  'Lenovo ThinkPad E15 G4 Key Specifications',
#  'ضمــــــان سنــــــة',
#  'ضمـــــــان سنـــــة',
#  'ASUS TUF A15 FA507NVR-LP007W',
#  'Asus Vivobook 15 X1502ZA-BQ007W',
#  'Plug-and-Play',
#  'ضمـــــــان سنـــــة',
#  'Fast Cooling and Low Noise',
#  'MEETION CP3030 Gaming Cooling Pad',
#  'Meetion SP1001 Office Strip Desktop Speakers',
#  'High-Fidelity Sound Quality',
#  'Processor',
#  'Processor',
#  'Processor',
#  'Samsung 990 EVO 5.0 NVMe SSD',
#  'HP ProBook 450 G10',
#  'Lenovo IdeaPad Slim 3 15IAH8 (83ER007YED)',
#  'ضمــــــــان سنتــين',
#  'ASUS TUF A15 2024 FA506NCR-HN007W',
#  'DIMM Type:',
#  'Crucial 16GB DDR5-5600 SODIMM',
#  'Crucial MX500 2TB 3D NAND SATA 2.5 Inch Internal SSD',
#  'ضمــــــــان سنتــين',
#  'Processor:\xa0',
#  'Processor',
#  'Processor',
#  'ضمــــــان سنــــــة',
#  'Key Specifications:',
#  'Processor',
#  'Processor',
#  'Type:',
#  'WD Blue SN580 NVMe SSD - 2TB',
#  'WD Blue SN580 NVMe™ SSD - 500GB',
#  'Usage:',
#  'OS',
#  'ضمـــــــان سنـــــة',
#  'ضمـــــــان سنـــــة',
#  'ضمــــان سنتيــــن',
#  None,
#  'Brand:',
#  'Brand:',
#  'Brand:',
#  'Water Repellent:',
#  'Waterproof Material',
#  'ضمـــــــــان سنــــة',
#  None,
#  'Material',
#  None,
#  None,
#  'Urban Elite Business Fashion Men’s Backpack',
#  'Design and Comfort',
#  None,
#  'Meinaili 1901 Business Anti-Thief Travel Laptop Backpack',
#  None,
#  'ضمـــان وكيـل سنتيـن',
#  'ضمــــــان سنــــــة',
#  'Form Factor',
#  'ضمــــــان سنــــة',
#  None,
#  None,
#  'OS:',
#  None,
#  'ضمـــان وكيـل سنتيـن',
#  None,
#  None,
#  'Processor:',
#  'ضمــــــان سنــــة',
#  'ضمــــــان سنــــة',
#  None,
#  None,
#  None,
#  'Usage:',
#  None,
#  None,
#  'ضمــــــان سنــــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمــــــان سنــــة',
#  'ضمــــــان سنــــة',
#  'ضمــــــان سنــــة',
#  'ASUS VivoBook 15 D1502YA-NJ007W',
#  'ضمــــــان سنــــة',
#  None,
#  'ضمــــــــان سنـــــة',
#  None,
#  '7450 MB/s (read)',
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــان وكيـل سنتيـن',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمــــــان سنــــــة',
#  'ضمــــــان سنــــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  'Processor:',
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  None,
#  'ضمـــان وكيـل سنتيـن',
#  None,
#  None,
#  'ضمــــــــان سنـــــــــة',
#  None,
#  'ضمــــــان سنــــــة',
#  'ضمــــــان سنــــــة',
#  'ضمــــــان سنــــــة',
#  None,
#  'WD Blue SN580 NVMe™ SSD - 1TB',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JSAUX CV0011 8K HDMI Cable 2.1',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــان وكيـل سنتيـن',
#  'ضمـــــــــان سنتــــين',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  'ضمـــــــــان سنــــة',
#  None,
#  'ضمـــــان سنـــــــــــة',
#  'ضمــــــان سنــــــة',
#  'ضمــــــان سنــــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Specifications',
#  None,
#  None,
#  None,
#  None,
#  'ضمــــــــان سنـــــــــة',
#  None,
#  None,
#  'ضمــــــــان سنـــــــــة',
#  None,
#  'ضمــــــــان سنـــــــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JSAUX HB0501 USB-C 5-in-1 Adapter :',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمــــــــان سنـــــــــة',
#  'ضمــــــــان سنــــــــة',
#  'ضمـــــان سنـــــــة',
#  'ضمـــــان سنـــــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Asus TUF FX507ZC4-HN081W Gaming Laptop',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Lenovo 100 Stereo Analog Headset',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'يرجى ملاحظة أن هذا الماوس لا يدعم سوفت وير',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمـــــــان سنــــــة',
#  'ضمـــــــان سنــــــة',
#  'ضمـــــان سنـــــــــة',
#  None,
#  None,
#  None,
#  'ضمــــــــان سنــــــة',
#  None,
#  'ضمـــــان سنـــــــــة',
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  'ضمـــــــــان سنــــة',
#  None,
#  None,
#  None,
#  'Height Adjustment:',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمــــــــان سنــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمــــان سنــة',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Processor',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمان وكيل MSI ف مصر',
#  'ضمان وكيل MSI ف مصر',
#  None,
#  None,
#  'ضمان وكيل سنتين',
#  None,
#  'ضمان وكيل سنتان',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمان وكيل سنتان',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمان وكيل سنتين',
#  'ضمان وكيل سنتين',
#  'ضمان وكيل سنتين',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمان سنه',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ضمان وكيل',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Manufacturer Number : KVR26s19s8/8\r\nBrand : Kingston\r\nType of Ram : DDR4\r\nCompatible with : Laptops\r\nKit Includes : Single Module\r\nMemory Speed : 2666 MHz\r\nModel Number : KVR26s19s8/8\r\nMemory Size : 8 GB',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Redragon IVY GCP500 Laptop Cooler',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Processor',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Processor:',
#  None,
#  None,
#  None,
#  None,
#  'Sound Quality',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Description: ',
#  None,
#  'Features',
#  None,
#  None,
#  'GEFORCE®\xa0GTX 1660 SUPER, THE NEW SUPERCHARGER.',
#  'Dell Cinema',
#  'Powerful on the surface',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Slim and Lightweight for Portable Cooling',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
x
# Out:
# ['ضمــــــان سنــــــة\nProcessor\xa0\r\n12th Generation Intel(R) Core( TM) i5-1235U (12MB Cache, up to 4.4 GHz, 10 cores)\r\nGraphics\r\nIntel(R) UHD Graphics\r\nMemory\xa0\r\n8GB, 1x8GB, DDR4, 2666MHz\r\nStorage\xa0\r\n256GB M.2 PCIe NVMe Solid Stat e Drive\r\nDisplay\r\n15.6 inch FHD (1920 x 1080) 120Hz 250 nits WVA Anti- Glare L ED Backlit Narrow Border Display\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــــان سنـــــــــة\nHP Victus 16-r1062ne\xa0laptop:\n\nProcessor: Intel Core i5-14450HX\r\n\r\n\t\nCores/Threads: 10 cores (6 performance cores + 4 efficient cores), 16 threads\nCache: 24MB\n\n\nGraphics Card: NVIDIA GeForce RTX 3050 with 6GB GDDR6 VRAM\nRAM: 16GB DDR5 (2 x 8GB modules) with a blazing-fast 5600 MHz speed\nStorage: 1TB SSD Gen4 (ultra-fast NVMe storage for quick boot and load times)\nDisplay: 16.1-inch FHD IPS display with a 144Hz refresh rate (provides smooth and vibrant visuals, perfect for gaming and content creation)\n\n',
#  'ضمــــــــان سنـــــــــــة\nHP Victus 16-r1066ne gaming laptop specifications updated:\n\nProcessor: Intel Core i5-14450HX\r\n\r\n\t\nCores/Threads: 10 cores (6 performance + 4 efficiency) / 16 threads\nDesigned for high-performance gaming and multitasking\n\n\nGraphics Card: NVIDIA GeForce RTX 3050 with 6GB of VRAM\r\n\t\nExcellent for gaming, rendering, and other GPU-intensive tasks\n\n\nRAM: 16GB DDR5 (2 x 8GB modules) at 5600MHz\r\n\t\nDual-channel configuration for optimized memory performance\n\n\nStorage: 1TB SSD Gen4\r\n\t\nUltra-fast read/write speeds for quicker load times and system responsiveness\n\n\nDisplay: 16.1-inch Full HD (1920x1080) IPS panel with a 144Hz refresh rate\r\n\t\nSmooth, crisp visuals perfect for gaming and multimedia\n\n\n\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack (Black)\nLaptop Stand Creative Folding\nLGC CMU02 Wireless Mouse\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــة\xa0\n\nModel: MSI Modern 15 F13MG\nProcessor: Intel Core i5-1335U (13th Gen, up to 4.60 GHz) (\xa010 cores &\xa012 threads )\nRAM: 8GB DDR4\nStorage: 512GB NVMe SSD\nGraphics: Intel Iris Xe Graphics\nDisplay: 15.6" FHD (1920x1080)\xa0IPS-Level\nConnectivity: Wi-Fi 6E, Bluetooth v5.3\nPorts: USB-A, USB-C, HDMI, RJ45, Micro SD\nOS: Free DOS\nWarranty: 1 Year\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــــة\nLenovo LOQ 15IRX9 Key Specs\n\nProcessor: Intel® Core™ i7-13650HX (14C/20T, up to 4.9GHz)\nGPU: NVIDIA® GeForce RTX™ 4050 (6GB GDDR6, 105W TGP, G-SYNC®)\nDisplay: 15.6" FHD IPS, 144Hz, 100% sRGB\nMemory: 16GB DDR5-4800 (upgradable to 32GB)\nStorage: 512GB PCIe® 4.0 SSD (supports up to 2TB)\nBattery: 60Wh\nWeight: 2.38 kg\nConnectivity: Wi-Fi 6, Bluetooth 5.2, HDMI® 2.1, USB-C® (140W PD)\nDurability: MIL-STD-810H certified\n\n',
#  'ضمـــــــان سنتـــــين وكــــــيل\nMSI Vector 16 HX A14VHG-801EG\nA high-performance laptop designed for gamers and professionals.\nKey Features:\n\nProcessor: Intel Core i9-14900HX (14 cores, 24 threads)\nGraphics Card: NVIDIA GeForce RTX 4080 (12GB GDDR6)\nRAM: 32GB DDR5 (expandable)\nStorage: 1TB NVMe PCIe Gen4x4 SSD\nDisplay: 16-inch QHD+ (2560x1600), 240Hz refresh rate, vibrant visuals\nOperating System: Windows 11 Home\n\nOther Highlights:\n\nCooling System: Advanced cooling for sustained performance\nConnectivity: Latest Wi-Fi 6E and multiple ports for flexibility\nDesign: Sleek and durable, ideal for mobility\n\n',
#  'ضمـــــــان سنتـــــين وكــــــيل\n\n\n\n\n\n\nMSI RAIDER 18 HX A14V\nSpecifications:\n\nProcessor: Latest Intel® Core™ i9-14900HX (14th Gen, powerhouse performance).\nGraphics: Up to NVIDIA® GeForce RTX™ 4090 Laptop GPU (16GB GDDR6, NVIDIA DLSS 3, Ada Lovelace, Max-Q).\nDisplay: 18" UHD+ MiniLED (3840x2400), 16:10, 240Hz, 100% DCI-P3, VESA DisplayHDR™ 1000 Certified – stunning visuals with IPS-level panel.\nOperating System: Windows 11 Home / Pro (recommended Pro for business).\nCooling: Cooler Boost 5 (dual fans, 6 heat pipes, 3D cooling stands).\nBattery: 99.9Whr for extended productivity.\nSound: Premium 6-speaker system by Dynaudio for immersive audio.\nWebcam: IR FHD with shutter, HDR, and 3D Noise Reduction.\nAesthetics: Mystic Light with Matrix Lightbar for next-level customization.\n\n\n\n\n\n\n\n',
#  'ضمــــــان ثلاث سنــــوات\nSamsung M80D Smart Monitor 32-Inch (LS32DM801UUXEN) Specifications:\n\xa0 \xa0 Key Features:\r\n\xa0 \xa0 \xa0 \xa0 Height-adjustable Smart AI monitor with built-in speakers and pivot function.\r\n\xa0 \xa0 \xa0 \xa0 UHD resolution with 4K AI upscaling for fluid, razor-sharp images at 60 Hz refresh rate.\n\xa0 \xa0 Smart Capabilities:\r\n\xa0 \xa0 \xa0 \xa0 Easy wireless access to PC files and IoT device control via Smart Hub.\r\n\xa0 \xa0 \xa0 \xa0 Access a variety of streaming services with directly selectable smart TV apps.\n\xa0 \xa0 Connectivity:\r\n\xa0 \xa0 \xa0 \xa0 Compatible with Xbox, PlayStation, PC, and laptops.\r\n\xa0 \xa0 \xa0 \xa0 Ports: 1x HDMI, 1x USB-C, 1x USB-A.\r\n\xa0 \xa0 \xa0 \xa0 Connectivity: WLAN, Bluetooth.\r\n\xa0 \xa0 \xa0 \xa0 Includes a SolarCell remote control and webcam.\n\xa0 \xa0 Advanced Display Features:\r\n\xa0 \xa0 \xa0 \xa0 HDR10+ support for deeper blacks and enhanced brightness to reveal all details.\r\n\xa0 \xa0 \xa0 \xa0 Eye Saver Mode to reduce blue light emissions.\r\n\xa0 \xa0 \xa0 \xa0 Flicker-Free Technology to eliminate screen flickering.\r\nWarranty 3-Year\n',
#  '\n\n\n\n\nTechnical Specifications:\n\n\nProcessor (CPU):\n\nIntel® Core™ i5-13500H\nUp to 4.7 GHz with Intel® Turbo Boost Technology\n18 MB L3 cache\n12 cores, 16 threads\n\n\n\nMemory (RAM):\n\n16 GB DDR5-5200 MT/s (2 x 8 GB)\nTransfer rates up to 5200 MT/s\n\n\n\nStorage:\n\n512 GB PCIe® Gen4 NVMe™ M.2 SSD\n\n\n\nGraphics (GPU):\n\nNVIDIA® GeForce RTX™ 3050 Laptop GPU\n6 GB GDDR6 dedicated memory\n\n\n\nDisplay:\n\n16.1" diagonal (40.9 cm)\nFHD (1920 x 1080) resolution\n144 Hz refresh rate\nIPS panel, micro-edge, anti-glare\n250 nits brightness, 45% NTSC color gamut\n\n\n\nCamera:\n\nHP True Vision 1080p FHD camera\nTemporal noise reduction\nDual-array digital microphones\n\n\n\nColor:\n\nPerformance Blue with a chrome logo\n\n\n\nKeyboard:\n\nArabic & English layout\n\n\n\nOperating System (OS):\n\nWithout OS\n\n\n\nAccessories:\n\nNone\n\n\n\n\n\n\n\n\n\n\xa0\n\n\n\n',
#  'MSI Thin 15 B13VE laptop specifications:\nSpecifications:\n\nProcessor: Intel Core i7-13620H (10 Cores, 16 Threads)\nRAM: 16GB DDR4 3200MHz (2x8GB)\nStorage: 512GB SSD (Gen4) + 2.5" HDD/SSD slot\nGraphics Card: NVIDIA GeForce RTX 4050, 6GB GDDR6 (45W TGP)\nDisplay: 15.6" FHD (1920x1080), IPS, 144Hz\nKeyboard: Blue Backlit, Arabic layout\nWeight: 1.86 kg\nWarranty: 2 Years\nModel Code: THIN15B13VE-9S7-16R831-2614\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمـــــــان سنتـــــين وكــــــيل\nMSI Thin 15 B12UCX is a powerful yet portable laptop, ideal for gamers, students, and creators.\nSpecifications\n\nProcessor: Intel Core i5-12450H (12th Gen)\nGraphics: NVIDIA GeForce RTX 2050, excellent for gaming and creative work.\nMemory: 8GB DDR4 (3200MHz) – expandable for multitasking needs.\nStorage: 512GB SSD – fast boot times and ample storage.\nDisplay: 15.6" FHD IPS, 144Hz – smooth visuals and vibrant colors.\nKeyboard: Blue backlit, Arabic support – perfect for night use and regional preferences.\nWeight: 1.86 kg – lightweight for its power.\nWarranty: 2 years for peace of mind.\n\n',
#  'ضمــــــان سنــــة\nASUS TUF Gaming F15 FX507ZI4-LP34W\r\nA beastly gaming laptop designed for enthusiasts. Here\'s a quick rundown:\n\nProcessor: Intel Core i7-12700H (14 cores, high-performance).\nGraphics Card: NVIDIA GeForce RTX 4070 (8GB GDDR6).\nMemory: 16GB DDR4 RAM, upgradeable.\nStorage: 512GB SSD (fast boot and load times).\nDisplay: 15.6" Full HD (1920x1080) with 144Hz refresh rate.\nOS: Windows 11 Home pre-installed.\nBuild: Sturdy design in a sleek gray finish, ideal for gaming on the go.\n\nThis laptop is perfect for gamers, content creators, and power users seeking high performance with reliable build quality.\n',
#  'JSAUX 8K@60Hz HDMI Cable - Premium Ultra-High-Definition Experience\n\nResolution & Performance: Supports 8K@60Hz, 4K, 1080p, and 720p resolutions with ultra-fast data transfer rates up to 48Gbps. Ideal for movies, gaming, and high-refresh-rate setups.\nBuild Quality: Aluminum alloy housing with durable nylon braiding and corrosion-resistant gold connectors for superior video and audio transmission.\nAdvanced Features:\r\n\t\nHDR10, Dolby Atmos, and Dolby Vision support for lifelike visuals and immersive sound.\nARC/eARC for enhanced audio return.\nAutomatic Low Latency Mode (ALLM) and Variable Refresh Rate (VRR) for smooth, lag-free performance.\nQuick notification switching for seamless usage.\n\n\nCompatibility: Works with Blu-ray players, Fire TV, Apple TV, PS5/PS4/PS3, Xbox consoles, Nintendo Switch, PCs, laptops, and monitors.\nCable Length: 3 meters, suitable for versatile use in home or office setups.\n\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack for School and Travel (Red)\nKey Features:\n\nReliable and Functional: Designed for school, travel, and everyday activities.\nPremium Durability: Crafted from strong Oxford fabric for lasting use.\nComfortable Design: Lightweight with ergonomic, padded straps for maximum comfort.\nSpacious Fit: Supports laptops up to 15.6 inches, with ample room for books and accessories.\nBold Aesthetic: Eye-catching red color for a stylish and dynamic look.\n\nCombining practicality and striking design, it’s your go-to backpack!\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack for School and Travel (Purple)\nKey Features:\n\nReliable Design: Tailored for school, travel, and everyday use.\nDurable Material: Made from strong Oxford fabric for excellent longevity.\nComfortable Wear: Lightweight with padded, ergonomic straps for hassle-free carrying.\nSpacious Storage: Fits laptops up to 15.6 inches, with additional compartments for books and accessories.\nUnique Style: Vibrant purple color that stands out with a modern and elegant touch.\n\nA perfect blend of durability, comfort, and style!\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack for School and Travel (Navy Blue)\nKey Features:\n\nReliable and Versatile: Perfect for school, travel, and daily use.\nDurable Build: Made with strong Oxford fabric for long-lasting performance.\nLightweight Comfort: Ergonomic design with sturdy, padded straps for comfortable wear.\nSpacious Fit: Accommodates laptops up to 15.6 inches, with multiple compartments for organized storage.\nStylish Appeal: Elegant navy blue finish for a sleek and professional look.\n\nA practical and stylish choice for your on-the-go needs!\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack for School and Travel (Gray)\nKey Features:\n\nReliable Design: Ideal for school, work, and travel.\nPremium Material: Crafted from strong Oxford fabric for enhanced durability.\nComfort First: Lightweight construction with ergonomic, sturdy straps for all-day comfort.\nSpacious Capacity: Fits laptops up to 15.6 inches, with extra compartments for accessories and books.\nModern Look: Sleek gray color, combining style with practicality.\n\nBuilt for convenience and durability—your perfect everyday companion!\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack for School and Travel (Blue)\nKey Features:\n\nReliable Design: Designed for school, work, and travel.\nMaterial: Made from strong Oxford fabric, ensuring durability and resistance to wear and tear.\nComfortable: Lightweight yet sturdy with ergonomic straps for extended use.\nCapacity: Fits laptops up to 15.6 inches, alongside books and other essentials.\nStylish & Practical: Modern blue design with multiple compartments for organized storage.\n\n\xa0\n\xa0\n\xa0\n',
#  'Sigma Laptop Backpack\n\nColor: Black\nPurpose: Ideal for school, travel, and daily use.\nMaterial: Made with strong Oxford fabric for durability.\nComfort: Lightweight with comfortable and sturdy design.\nCompatibility: Fits laptops up to 15.6 inches.\n\nA reliable choice for students and travelers seeking both style and functionality.\n\xa0\n\xa0\n\xa0\n',
#  'Introduction\nThe E100N series solid state drive is the result of years of experience and expertise in storage technology and flash memory management. This product is designed to optimize computer operating systems, offering stable and fast data service by accelerating startup times and overall performance.\nFeatures\n\nHigh R/W Speed (SATA Interface):\n\nMax. Read Speed: Up to 560 MB/s\n\n\n3D NAND Technology:\n\nProvides higher capacity, performance, and stability\n\n\nVibration-Resistant Structure:\n\nNo mechanical components; electronic chip control ensures better data safety\n\n\nApplication Field:\n\nIdeal for personal computers, laptops, and other devices.\n\n\n\n',
#  '\nHighlights:\n\nHigh-Speed Transmission: The maximum read speed is up to 450MB/s, which is 4 times faster than a mechanical hard disk.\nCapacity Expansion for Mobile Phones: Can connect to Android phones, Android tablets, and other devices via OTG cables for expanded storage.\nShock Resistant and Heat Dissipation: The metal case helps dissipate heat effectively. The consumer SSD uses the E2000 M.2 interface.\n3D NAND Flash: Stereoscopic storage technology allows each storage unit to be more compact, greatly improving the storage capacity of flash memory.\r\n\t\xa0\r\n\tOverview:\nIntroduction\nThe T200N Portable SSD is designed to expand storage capacity for Android phones, Android tablets, PCs, and laptops via the USB 3.1 Type-C interface, addressing the need for long-term, large-capacity storage. The T200N series SSD is popular among individuals, designers, and video editors who require reliable, fast storage.\n\n\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــان ســــنة\xa0\n\nProcessor: AMD Ryzen™ 5 5600H (6 cores, 12 threads, up to 4.2 GHz)\nGraphics: AMD Radeon™ RX 6500M (4 GB GDDR6)\nMemory: 8 GB DDR4-3200\nStorage: 512 GB PCIe® Gen4 NVMe™ SSD\nDisplay: 15.6" FHD (1920 x 1080), 144 Hz, IPS, 250 nits brightness\nBattery: 52.5 Wh, up to 8.5 hours, fast charge (50% in 45 mins)\nWi-Fi: Wi-Fi 6, Bluetooth® 5.3\nPorts: USB Type-C®, USB Type-A, HDMI 2.1, RJ-45, headphone/mic combo\nWeight: 2.29 kg\nEco Features: Contains recycled plastic materials\n\n',
#  'ضمــــان سنتيــــن\nGIGABYTE G6X 9KG laptop:\n\nProcessor: Intel® Core™ i7-13650HX (14 cores, 20 threads, up to 4.9 GHz)\nGraphics: NVIDIA® GeForce RTX™ 4060 (8GB GDDR6)\nDisplay: 16.0" WUXGA (1920x1200), 165Hz, 16:10 aspect ratio\nMemory: 16GB DDR5 (upgradable to 64GB)\nStorage: 512GB M.2 SSD (2x M.2 slots, supports up to 4TB)\nKeyboard: RGB Backlit, 1.5mm key travel\nPorts: USB Type-A, Type-C, HDMI 2.1, RJ-45, Audio jack\nConnectivity: Wi-Fi 6E, Bluetooth 5.2\nBattery: 73Wh, 180W AC Adapter\nWeight: ~2.5 kg (~5.64 lbs)\nSecurity: TPM, Kensington Lock Slot\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــان سنتيــــن\xa0\n\n\nAORUS 16X 9SG 2024:\n\nProcessor: Intel® Core™ i7-13650HX (6 P-cores, 8 E-cores, up to 4.9 GHz) (14c-20t)\nGraphics: NVIDIA® GeForce RTX™ 4070 Laptop GPU, 8GB GDDR6\nDisplay: 16.0" 16:10 WQXGA (2560x1600), 165Hz, 100% sRGB, Dolby Vision®, G-SYNC\nMemory: 2 x DDR5 slots (up to 64GB, DDR5-4800MHz)\nStorage: 2 x M.2 SSD slots, each 1TB\nKeyboard: 3-zone RGB, 1.7mm key travel, N-Key rollover\nPorts:\r\n\t\nLeft: 1 x DC in, 1 x RJ-45, 1 x HDMI 2.1, 1 x Type-A USB 3.2, 1 x Type-C Thunderbolt™ 4\nRight: 1 x Type-A USB 3.2, 1 x Type-C USB 3.2, 1 x MicroSD, 1 x Audio Jack\n\n\nAudio: 2 x 2W speakers, Dolby Atmos®, Smart Amp Technology\nWebcam: FHD (1080p) IR webcam, Windows Hello support\nDimensions: 35.6 x 25.4 x 2.02.7 cm (14.01 x 10 x 0.781.06 inches)\nWeight: ~2.3 kg (5.07 lb)\nColor: Midnight Gray\n\n',
#  'Acer Nitro V Gaming Laptop (ANV15-51-532J) specs:\n\nProcessor: Intel Core i5-13420H (Cores: 6\xa0Threads: 12 threads\xa0)\nGPU: NVIDIA GeForce RTX 3050\xa06GB version Laptop GPU (Good for gaming with ray tracing support)\nDisplay: 15.6" FHD IPS, 144Hz (Smooth visuals with high refresh rate for gaming)\nRAM: 8GB DDR5 (Fast memory, but upgradeable for more intensive tasks)\nStorage: 512GB Gen 4 SSD (Fast storage, good for gaming and apps)\nConnectivity: WiFi 6 (Fast and reliable wireless connection)\nKeyboard: Backlit (Great for gaming in low-light environments)\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــــة\xa0\n\nProcessor: Intel Core Ultra 7 155H (16 Cores, 3.8 GHz, up to 4.8 GHz Turbo)\nMemory: 16GB DDR5 (6400 MHz)\nStorage: 1TB M.2 SSD\nDisplay: 16-inch WUXGA (1920x1200), IPS, 300 nits, Touchscreen\nGraphics: Intel Arc Graphics\nOperating System: Windows 11 Home\nNetworking: Wi-Fi 6E and Bluetooth 5.3\nAudio: Quad Tuned Speakers with Dolby Atmos\nWeight: 2.18 kg\nWarranty: 1 Year On-Site Warranty\nColor: Ice Blue\n\n',
#  'The Lexar SL500M 1TB External SSD is a high-performance portable solid-state drive that offers impressive features for a variety of devices.\n\nStorage Capacity: 1TB, providing ample space for your data, games, media files, and more.\nInterface: USB 3.2 Gen2x2, ensuring fast data transfer speeds and compatibility with a wide range of devices.\nRead Speed: Up to 2000MB/s, allowing for ultra-fast access to your files, making it ideal for gaming, video editing, or any data-heavy tasks.\nMagnetic Set: The inclusion of a magnetic set allows the drive to be mounted securely on compatible surfaces, offering added convenience for portability.\nSlim and Compact Design: Ultra-slim, lightweight form factor, making it easy to carry around and use on-the-go.\nCompatibility: Works seamlessly with devices like iPhone 15 Series, Mac, PS5, Xbox, laptops, and PCs, making it versatile for different needs and platforms.\n\n\xa0\n\xa0\n\xa0\n',
#  "The Lexar SL500M 1TB External SSD is a high-performance portable storage solution that offers fast read speeds and excellent compatibility across a variety of devices.\n\nStorage Capacity: 1TB of high-speed storage, perfect for storing large files, games, videos, and more.\nSpeed: Equipped with USB 3.2 Gen 2x2 interface, it delivers up to 2000MB/s read speeds, providing rapid file transfers.\nMagnetic Set: Comes with a magnetic set for secure mounting, ideal for use in tight spaces or when you need to keep it in place.\nCompact Design: Ultra-slim and lightweight, making it portable and easy to carry on the go.\nWide Compatibility: Works seamlessly with devices like the iPhone 15 series, Mac, PS5, Xbox, laptops, and PCs. It's perfect for gamers, professionals, or anyone who needs quick access to large amounts of data.\n\n\xa0\n\xa0\n\xa0\n",
#  '\nType: Internal SSD\nForm Factor: M.2 2280\nInterface: NVMe 1.4, PCIe Gen3x4\nCapacity: 1TB\nRead Speed: Up to 3300 MB/s\nWrite Speed: Up to 2600 MB/s\n\n',
#  'Lexar 2TB Professional NM800 PRO SSD with Heatsink - Key Specs:\n\nForm Factor: M.2 2280\nInterface: PCIe Gen4 x4, NVMe 1.4\nSpeed: Up to 7500 MB/s (Read), 6500 MB/s (Write)\nCompatibility: PS5, PCs, Laptops\nCooling: Integrated heatsink\nUse Case: Gamers, Creators, Professionals\n\n\xa0\n\xa0\n\xa0\n',
#  'Here are the key specifications for the Lexar DDR5 SODIMM Laptop Memory:\n\nCapacity: 16 GB (1 x 16 GB)\nType: DDR5 SODIMM\nSpeed: 4800 MHz\nCAS Latency: CL40\nVoltage: 1.1V\nCompatibility: Laptops with DDR5 support\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــة\nHere’s a concise summary of the key specifications for the ASUS TUF Gaming A15 FA507NUR-LP007W:\nKey Specifications:\n\nProcessor: AMD Ryzen™ 7 7435HS (3.1GHz, up to 4.5GHz, 8 cores, 16 threads)\nGraphics: NVIDIA® GeForce RTX™ 4050 (6GB GDDR6)\nRAM: 16GB DDR5-4800 (Dual channel support)\nStorage: 512GB M.2 NVMe™ PCIe® 4.0 SSD\nDisplay: 15.6-inch FHD (1920 x 1080), 144Hz, IPS-level, 100% sRGB\nOS: Windows 11\nKeyboard: Backlit Chiclet Keyboard with 1-Zone RGB\nColor: Graphite Black\n\n',
#  'ضمــــــان سنــــة\nKey Specifications:\n\nProcessor: Intel® Core™ i7-13620H, up to 4.9 GHz, 10 cores\nMemory: 16GB (8GB DDR5-4800 SO-DIMM x2)\nStorage: 1TB PCIe® 4.0 NVMe™ M.2 SSD\nGraphics: NVIDIA® GeForce RTX™ 4070, 8GB GDDR6\nDisplay: 15.6-inch FHD (1920 x 1080), 144Hz\nOperating System: Windows 11 Home\nColor: Jaeger Gray\n\n',
#  'ASUS ROG Strix G16 G614JV-N3487W – Key Specs\n\nOS: Windows 11 Home\nProcessor: Intel Core i7-13650HX (13th Gen) – 14 cores (6P + 8E), up to 4.9 GHz\nGPU: NVIDIA GeForce RTX 4060, 8GB GDDR6, 140W\nDisplay: 16" FHD+ (1920x1200), IPS, 165Hz, 100% sRGB, G-Sync, Dolby Vision\nRAM: 16GB DDR5 (upgradable to 32GB)\nStorage: 1TB PCIe 4.0 NVMe SSD\nPorts: Thunderbolt 4, USB-C, HDMI 2.1, RJ45 LAN\nNetwork: Wi-Fi 6E, Bluetooth 5.3\nKeyboard: RGB Backlit (4-zone)\nAudio: Dolby Atmos, AI noise cancellation\nCamera: 720p HD\nBattery: 90Wh, 280W charger\nWeight: 2.5 kg\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــــة\xa0\n\nProcessor: Intel® Core™ i5-13450HX (10C, 16T, up to 4.6 GHz)\nGraphics: NVIDIA® GeForce RTX™ 3050 (6GB GDDR6)\nMemory: 16GB SO-DIMM DDR5-4800 (up to 32GB)\nStorage: 512GB SSD (M.2 2242 PCIe® 4.0x4) + supports up to 2 drives\nDisplay: 15.6" FHD (1920x1080), 144Hz, G-SYNC®\nWeight: Starting at 2.38 kg (5.25 lbs)\nConnectivity: Wi-Fi® 6, Bluetooth 5.2, various USB ports, HDMI® 2.1\nBattery: Integrated 60Wh\nOperating System: None (OS not included)\nSecurity: Firmware TPM 2.0, E-shutter\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــــــان سنـــــــــة\nKey Specifications:\n\nProcessor:\xa0AMD Ryzen 3 5300U (4 Cores / 8 Threads, Base 2.6GHz, Boost up to 3.8GHz)\nGraphics:\xa0AMD Radeon Integrated Graphics\nMemory:\xa08GB DDR4 3200MHz (Expandable)\nStorage:\xa0256GB NVMe SSD (Fast boot and load times)\nDisplay:\xa015.6-inch Full HD (1920x1080), VA Panel (Better viewing angles and color than TN)\nOperating System:\xa0Usually ships with FreeDOS (can upgrade to Windows 10/11)\nPorts:\xa0USB-C, USB-A, HDMI, headphone jack, SD card reader\nConnectivity:\xa0Wi-Fi 5, Bluetooth 5.0\nBattery:\xa0~41Wh (provides decent 6-8 hours on light use)\nWeight:\xa0~1.7 kg\n\n',
#  'Key Features:\n\n\nPerformance for Gamers & Creators:\n\nFast load times for games and applications.\nSmooth data access, perfect for heavy workloads like video editing or rendering.\n\n\n\nDurability and Reliability:\n\nBuilt with 3D TLC NAND for a good balance between performance and longevity.\nRated for 1,500 TBW, ensuring a long product life.\n\n\n\nThermal Management:\n\nThe drive features built-in thermal throttling protection to maintain optimal performance under heavy loads.\n\n\n\nCompatibility:\n\nWorks with PCs, laptops, and compatible gaming consoles that support PCIe Gen 3 x4 NVMe SSDs.\n\n\n\nSoftware Support:\n\nOffers KLEVV Data Migration Tool for easy data transfer and drive management.\n\n\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمـــــــــان سنـــــــــــة\xa0\n\nOperating System: FreeDOS 3.0\nProcessor: Intel® Core™ i7-14700HX (up to 5.5 GHz, 20 cores, 28 threads)\nGraphics: NVIDIA® GeForce RTX™ 4050 (6 GB GDDR6)\nMemory: 16 GB DDR5-5600 MT/s\nInternal Storage: 1 TB PCIe® Gen4 NVMe™ M.2 SSD\nDisplay: 16.1 inches, FHD (1920 x 1080), 144 Hz, IPS\nBattery: 70 Wh, up to 5 hours and 15 minutes\nDimensions: 36.9 x 25.94 x 2.29 cm (front) / 36.9 x 25.94 x 2.39 cm (rear)\nWeight: 2.33 kg\n\n',
#  'ضمـــــــان سنـــــة\xa0\n\nProcessor: Intel® Core™ i7-14700HX (20 cores, up to 5.5GHz) (28\xa0Threads)\nRAM: 16GB\xa0DDR5\xa05600 MT/s (2 x 8 GB)\nStorage: 512GB PCIe® Gen4 NVMe™ SSD\nGraphics: NVIDIA® GeForce RTX™ 4050 (6GB GDDR6)\nDisplay: 16.1" FHD, 144Hz, IPS, 300 nits\nKeyboard: Full-size, Backlit (Performance Blue) with Numeric Keypad\nConnectivity: Wi-Fi 6E, Bluetooth® 5.3, LAN, USB-C with Power Delivery\nBattery: 4-cell, 70Wh, 230W charger\nWeight: ~2.5 kg\nOS: DOS (No pre-installed OS)\n\n',
#  'PROFESSIONAL GRADE WIRED GAMING MOUSE; featuring ultra-fast lag free wired\xa0connection. Pro Gaming features with 16000 user adjustable DPI and 40G acceleration. The High-Precision Sensor delivers Pinpoint Accuracy and extreme responsiveness during PC Gaming or Computer editing\nRGB BACKLIT PROGRAMMABLE PC GAMING MOUSE; with 8 Lighting Effects, 10 Brightness Levels, Breathing Modes, (Backlight can be disabled), 9 user programmable buttons, 2 Side Buttons, Rapid Fire Button, 5 Memory Profiles with Macro Recording\nERGONOMIC GAMER MOUSE; Delivering an extremely comfortable and precise experience for Computer Games.\nMMO GAMING MOUSE FEATURES; The Redragon M801P RGB Mouse features; Set Anti-Skid Scroll Wheel, Durable smooth TEFLON feet pads for ultimate gaming control. 9 programmable buttons. Comes with detachable 6 foot,\xa0\nPC GAMING MOUSE COMPATIBILITY: Windows 10, Windows 8, Windows 7, Windows Vista, or Windows XP, Limited Mac OS support Works well with all major Gaming Computers Brands and Gaming Laptops.\n\xa0\n\xa0\n\xa0\n',
#  "The PNY CS2130 2TB M.2 PCIe NVMe Gen3 x4 Internal Solid State Drive is a high-performance SSD aimed at both casual users and professionals, such as gamers, creators, and students. Here’s a breakdown of its key features:\nKey Specs:\n\nStorage Capacity: 2TB\nForm Factor: M.2 2280\nInterface: PCIe Gen3 x4 NVMe 1.3\nRead Speed: Up to 3,500 MB/s\nWrite Speed: Up to 3,000 MB/s\nEndurance: Rated for high durability, with TBW (Total Bytes Written) expected to be quite robust.\nController: Phison E12 series\nMemory Type: 3D NAND\n\nKey Features:\n\nFast Data Transfer: With up to 3,500 MB/s read speeds, the drive offers quick boot times and fast loading of games and applications.\nReliable 3D NAND: Built for longevity and efficiency.\nLow Power Consumption: Ideal for laptops as it helps preserve battery life while maintaining performance.\nNo Moving Parts: As an SSD, it's more durable and resistant to shock than traditional hard drives.\nApplications:\r\n\t\nGreat for gaming with reduced load times.\nContent creators benefit from faster file transfers and program operations.\nIdeal for students needing reliable and fast storage.\n\n\n\n\xa0\n\xa0\n\xa0\n",
#  'Processor\nIntel® Core™ i7-13650HX Processor (24M Cache, up to 4.9 GHz, 14 cores : 6 P-core and 8 E-core)\nGraphics\nNVIDIA® GeForce RTX™ 4070 Laptop GPU 8GB GDDR6\nBoost Clock 2370MHz / Maximum Graphics Power 140 W\nMemory\n2x 8GB SO-DIMM DDR5-4800\nStorage\n1 Tera -\xa0 2x M.2 SSD slots (Supports 2x PCIe® Gen4x4 NVMe™ M.2 SSD, Up to 4TB)\nDisplay\n16.0“ 16:10 WQXGA (2560x1600) 165Hz Display（100% sRGB, Pantone® Validated, TÜV Rheinland-certified, Dolby Vision®, NVIDIA® Advanced Optimus, G-SYNC）\nOS: Windows 11 Pro\nwarranty : 2 years\n',
#  'ضمـــــــان ثلاث سنــــوات\nMSI Modern MD2412PW is a sleek 24-inch monitor designed for both productivity and aesthetics. Here’s a quick breakdown of its features:\nKey Specifications:\n\nScreen Size: 24 inches\nPanel Type: IPS (In-Plane Switching)\nResolution: 1920x1080 (Full HD)\nRefresh Rate: 100Hz\nResponse Time:\r\n\t\n1ms (MPRT - Motion Picture Response Time)\n4ms (GTG - Gray to Gray)\n\n\nDisplay Type: Flat\nConnectivity:\r\n\t\nType-C Port (great for modern laptops and phones)\nAdditional input options (e.g., HDMI, DisplayPort not listed explicitly)\n\n\nAdjustable Stand: Ergonomic design allowing height, tilt, and swivel adjustments for better comfort\nColor: White\n\nWhy it Stands Out:\n\nIPS Panel: Provides wider viewing angles and better color accuracy compared to TN panels.\n100Hz Refresh Rate: Smoother motion for work and casual gaming.\nType-C Port: A future-proof option, ideal for those who prefer fewer cables and easy connections with modern devices.\nDesign: The white color and modern build fit well in stylish office setups or home desks.\n\nThis model is ideal for content creators, professionals, and those looking for an elegant setup.\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــة\nThe ASUS TUF Gaming F15 FX507ZC4-HN002W is a solid gaming laptop with impressive specs for both gamers and content creators. Here’s a breakdown of its key features:\n\nSpecifications:\n\nProcessor: Intel Core i7-12700H (14 cores, 20 threads)\nRAM: 16GB DDR4 (expandable)\nStorage: 512GB SSD (M.2 NVMe PCIe)\nGraphics: NVIDIA GeForce RTX 3050 (4GB GDDR6)\nDisplay: 15.6” FHD (1920x1080) IPS, 144Hz refresh rate\nOperating System: Windows 11 Home\nColor: Mecha Gray\n\n\nPerformance & Gaming:\n\nIntel Core i7-12700H: A 12th-generation processor with a hybrid core architecture, ideal for handling demanding games and multitasking.\nRTX 3050: Offers good entry-level ray tracing and DLSS capabilities, making it suitable for most AAA games on medium to high settings.\n144Hz Display: Smooth visuals, reducing motion blur for an improved gaming experience.\n\n\nDesign & Battery Life:\n\nDesign: Military-grade build quality (TUF durability standard).\nCooling: Dual fans with self-cleaning technology to keep temperatures in check.\nBattery: Average battery life for general use, though gaming performance will likely require frequent charging.\n\n\nWho is it for?\n\nGamers: Can handle modern games efficiently with RTX graphics.\nContent Creators: Multitasking capabilities with i7-12700H.\nStudents/Professionals: Lightweight enough for everyday use but built for heavy performance when needed.\n\n',
#  "The Asus ROG Strix G17 G713PV-HX019W is a powerful gaming laptop that combines high-end performance with excellent visuals. Here’s a breakdown of its key specs:\n\nSpecifications:\n\n\nDisplay: 17.3-inch FHD (1920 x 1080) 144Hz\n\nGreat for smooth visuals during gameplay with minimal motion blur.\n\n\n\nProcessor: AMD Ryzen 9 7845HX\n\n12 cores, 24 threads – Ideal for demanding games and multitasking.\n\n\n\nGraphics: NVIDIA GeForce RTX 4060 (8GB GDDR6)\n\nHandles modern AAA titles and content creation with ray tracing support.\n\n\n\nRAM: 16GB DDR5\n\nHigh-speed memory ensures fast loading times and smooth multitasking.\n\n\n\nStorage: 1TB PCIe SSD\n\nPlenty of space for games, files, and fast data access.\n\n\n\nOperating System: Windows 11\n\nSupports the latest features and optimizations for gaming.\n\n\n\nExtras:\n\nROG Backpack: Practical for gamers on the go.\n90NR0C34-M00BL0: Model number for tracking the exact version.\n\n\n\n\nIdeal For:\n\nGamers: Enjoy high frame rates with the 144Hz display and RTX 4060 GPU.\nContent Creators: AMD R9 and RTX 4060 combo provide great video rendering performance.\nStudents and Professionals: Windows 11 makes it easy to balance productivity and gaming.\n\nThis laptop is a solid option if you're after a high-end gaming experience with excellent multitasking ability.\xa0\n\xa0\n\xa0\n\xa0\n",
#  'ضمــــان ثلاث سنــــوات\nThe\xa0AOC U27U3CV\xa0is a premium 27-inch monitor aimed at professionals, offering high resolution and advanced features suitable for tasks like content creation, graphic design, and video editing. Below is a summary of its key features:\nKey Specifications:\n\nDisplay Size:\xa027 inches\nResolution:\xa03840 x 2160 (4K UHD)\nPanel Type:\xa0IPS (In-Plane Switching)\nRefresh Rate:\xa060 Hz\nHDR Support:\xa0Yes (HDR10)\nBrightness:\xa0Typically around 350 nits\nColor Accuracy:\xa0Covers 99% sRGB and wide color gamut\nResponse Time:\xa04ms (GtG)\nViewing Angle:\xa0178° horizontal / 178° vertical\n\nConnectivity:\n\nUSB-C Port:\xa0Supports 65W Power Delivery for laptops and devices\nHDMI 2.0:\xa0Two ports\nDisplayPort 1.4:\xa0One port\nUSB Hub:\xa0Built-in USB-A ports for peripherals\nAudio Jack:\xa0Yes (3.5mm)\n\nDesign & Build:\n\nStand:\xa0Height, tilt, and pivot adjustable\nVESA Mount:\xa0100x100mm compatible\nBezels:\xa0Thin for multi-monitor setups\nBuild:\xa0Sleek and professional, part of the Graphic Pro Series\n\n',
#  'MOUSE: Special features Wireless Movement detection technology Optical Hand orientation Ambidextrous Compatible devices Laptop, Personal Computer Operating system Linux, Windows XP, Windows 7 Style Modern Hardware platform Laptop, Personal Computer\r\n+\r\nSTAND: Height Adjustment: Adds 6-7 inches of height to your laptop for a more comfortable viewing angle. Comfort Angle: Provides an ergonomic angle for better posture and comfort. Folding Design: Easy to store and transport. Materials: Made from plastic and aluminium alloy, ensuring durability and lightweight portability. Weight Capacity: Can support 15-20 kg, making it robust enough for various devices. Compatibility: Works with laptops, notebooks, and tablets ranging from 10 to 17 inches in size. This stand seems like a great addition for enhancing laptop ergonomics and comfort!\n\xa0\n\xa0\n\xa0\n',
#  'The HP Victus is a great gaming laptop! Here are some key features:\n\nProcessor: Intel i5-13500H with 12 cores, providing strong performance for gaming and heavy applications.\nRAM: 8GB, which might need an upgrade if you\'re running multiple programs or games that require more memory.\nStorage: 512GB SSD, fast and offers enough space for games and software.\nGraphics Card: GeForce RTX 3050 with 6GB, capable of running most modern games well.\nDisplay: 15.6" FHD with a 144Hz refresh rate, delivering a smooth gaming experience.\n\n\xa0\n\xa0\n\xa0\n',
#  "ضمـــــــان سنـــــة\nThe HP Victus 15-FA1043NE is an excellent choice for gaming! Here are some key details:\n\nProcessor: Intel Core i5-13500H (13th Gen), strong for gaming and multitasking.\nRAM: 8GB DDR4, sufficient for modern games, but you can upgrade if needed in the future.\nStorage: 512GB SSD, offers fast loading times for games and applications.\nGraphics Card: Nvidia RTX 3050 6GB, delivers good performance for medium to high-quality gaming.\nDisplay: 15.6-inch FHD with a 144Hz refresh rate, ideal for a smooth gaming experience.\n\nIf you're looking for good gaming performance at a reasonable price, this laptop could be a great fit.\n",
#  'The Lexar® JumpDrive® Dual Drive D400 is a 2-in-1 USB flash drive with both Type-C and Type-A connectors, allowing easy file transfers between devices. With high-speed USB 3.1 Gen1 performance and transfer speeds up to 130MB/s, it features a durable metal swivel design, key ring loop, and secure password protection with data encryption. Compatible with smartphones, tablets, laptops, and Macs, it offers reliable performance and durability for on-the-go use\nThis keeps it concise while highlighting the key features.\n\xa0\n\xa0\n\xa0\n',
#  '\xa0\n\n\n\n\n\n\nThe Samsung DDR5 SODIMM 16GB 4800MHz laptop RAM is designed for high-performance computing with the following specifications:\n\nMemory Type: DDR5 SODIMM\nCapacity: 16GB\nSpeed: 4800MHz\nLatency: CL40 (CAS latency of 40)\nDesign: 2 Rank (dual-rank) x8, 288-pin module\nVoltage: Typically operates at 1.1V (common for DDR5)\n\nThis memory module offers improved speed and bandwidth compared to DDR4, making it ideal for laptops that support DDR5 for demanding applications like gaming, content creation, and multitasking.\n\n\n\n\n\n\n\xa0\n\xa0\n\xa0\n',
#  'Lenovo ThinkPad E15 G4 Key Specifications\n\nProcessor: Intel Core i5-1235U (12th Gen)\nRAM: 8GB DDR4\nStorage: 512GB SSD\nGraphics: NVIDIA GeForce MX550 (2GB)\nDisplay: 15.6" FHD (1920x1080)\nConnectivity: Wi-Fi 6E, Bluetooth 5.1\nOperating System: Free DOS\n\n\xa0\n\xa0\n\xa0\n',
#  'ضمــــــان سنــــــة\xa0\n\nProcessor: Intel Core i7-1355U (13th Gen) – 10 Cores, 12 Threads, Up to 5.0 GHz\nGPU: NVIDIA GeForce MX550 (2GB GDDR6) – Good for light gaming & basic editing\nRAM: 8GB DDR4-3200 (Soldered) – Limited upgradability\nStorage: 512GB M.2 PCIe Gen4 SSD – Fast and reliable\nDisplay: 16" WUXGA (1920×1200) – 16:10 aspect ratio, ideal for productivity\nBattery: 57Wh – Up to 8-10 hours of moderate usage\nKeyboard: Non-backlit, Arabic layout\nPorts: HDMI 2.0, USB-A (x2), USB-C, Thunderbolt 4, RJ-45 Ethernet\nSecurity: Fingerprint reader integrated in power button\nWeight: 1.81 kg – Portable for a 16" device\nOperating System: DOS – Requires Windows or Linux installation\n\n',
#  'ضمـــــــان سنـــــة\nThe HP 250 G10 Laptop is a solid choice for both productivity and casual gaming. Here’s a quick overview of its features:\n\nProcessor: Intel Core i5-1335U, which provides good performance for multitasking and everyday tasks.\nRAM: 8GB, sufficient for most applications and general use.\nStorage: 512GB M.2 NVMe SSD, offering fast data access and ample space for files and applications.\nGraphics: Nvidia MX550 with 2GB dedicated VRAM, suitable for light gaming and graphic design tasks.\nDisplay: 15.6-inch FHD (1920 x 1080), providing clear and vibrant visuals.\nColor: Turbo Silver, giving it a sleek and modern look.\n\nOverall, it seems like a reliable laptop for office work, multimedia consumption, and some light gaming.\n\xa0\n\xa0\n\xa0\n',
#  "The ASUS TUF A15 FA507NVR-LP007W is a powerful gaming laptop designed for gamers who want high performance and reliability. Here's a breakdown of the key specifications:\n\n\nProcessor: AMD Ryzen 7 7435HS\r\n\tThis is a high-performance processor that delivers solid multi-core performance, making it suitable for gaming and demanding tasks like video editing or 3D rendering.\n\n\nStorage: 512GB SSD\r\n\tFast SSD storage ensures quick boot times and reduces load times in games and applications.\n\n\nRAM: 16GB\r\n\tProvides ample memory for multitasking, gaming, and running resource-heavy programs.\n\n\nDisplay: 15.6-inch FHD (Full HD, 1920 x 1080 resolution)\n\nsRGB 100%: Ensures accurate color representation, making it great for creative work such as photo editing.\n144Hz Refresh Rate: Delivers smooth gameplay, especially beneficial for fast-paced games where every frame counts.\n\n\n\nGraphics Card: NVIDIA GeForce RTX 4060 with 8GB GDDR6 VRAM\r\n\tThis is a powerful GPU for gaming, capable of running modern AAA games at high settings and offering support for ray tracing and AI-enhanced graphics.\n\n\nOperating System: Windows 11\r\n\tComes pre-installed with Windows 11, offering the latest features and improvements in gaming and productivity.\n\n\nColor: Jaeger Gray\r\n\tThe stylish design with a Jaeger Gray finish gives it a modern, sleek look.\n\n\nOverall, the ASUS TUF A15 is a solid option for gaming enthusiasts who also need a laptop for multitasking and content creation. The combination of the Ryzen 7 processor and the RTX 4060 ensures good performance across various scenarios.\n\xa0\n\xa0\n\xa0\n",
#  "The Asus Vivobook 15 X1502ZA-BQ007W is a sleek laptop with solid specifications, suited for both productivity and light to moderate tasks. Here's a breakdown of its key features:\n\nProcessor: Intel Core i7-12700H (12th Gen), offering high performance with multiple cores for multitasking, content creation, and demanding applications.\nStorage: 512GB SSD, providing fast data access and ample storage space for files and applications.\nRAM: 8GB DDR4, enough for general usage, though you might want to upgrade if you plan on handling heavier tasks like video editing or running virtual machines.\nDisplay: 15.6-inch FHD (Full HD) screen, offering a resolution of 1920x1080 pixels for crisp visuals.\nGraphics: Intel UHD Graphics, suitable for light gaming, video playback, and basic graphics tasks. It’s not designed for high-end gaming or demanding graphic design work.\nOperating System: Windows 11, with modern features and optimizations for performance and security.\nColor: Quiet Blue, adding a unique aesthetic touch.\nWeight & Design: Thin and portable design, making it easy to carry for work or school.\n\nThis model balances between performance and portability, making it a good choice for users who need a reliable device for everyday tasks without needing extreme graphical power.\n\xa0\n\xa0\n\xa0\n",
#  '\nPlug-and-Play: Easy setup with no additional drivers required.\nCompact USB Receiver: One nano receiver for both devices, optimizing USB port usage.\nCompatibility: Works with a range of USB-compatible devices like PCs, laptops, and tablets.\nDual-Language Support: Supports both English and Arabic, ideal for bilingual users.\nWireless Connectivity: Provides a clutter-free, wireless experience.\nLong Battery Life: Designed for extended use, reducing the need for frequent battery changes.\n\nIt’s a solid choice for those seeking a functional, multilingual, and hassle-free input solution.\n\xa0\n\xa0\n\xa0\n',
#  'ضمـــــــان سنـــــة\nHP 255 G8 Laptop\nModel: 7J034AA#ABV\nColor: BLACK\nOverview:\r\nStay productive and entertained on the go with the HP 255 G8 Laptop. Featuring a 15.6" Full HD display and powered by an AMD Ryzen 5 5500U processor, this laptop is designed for both work and play. Weighing less than 4 pounds, it’s easy to carry, and with up to 7 hours of battery life, you can work or stream content throughout your day.\nKey Features:\n\nPerformance: Equipped with a dual-core AMD Ryzen 5 5500U processor, 8GB RAM, and a 256GB SSD for smooth multitasking and quick access to your files.\nDisplay: 15.6" Full HD screen with integrated AMD Radeon Graphics for a crisp and immersive viewing experience.\nConnectivity: Includes USB 3.2 Gen 1 Type-C, two USB Type-A ports, HDMI, RJ45 Ethernet, and Bluetooth 5. Connect to wireless networks with Wi-Fi 5.\nVideo Conferencing: Built-in HD webcam, microphone, and speakers with HP Noise Cancellation for clear online meetings.\nSecurity: Firmware-based Trusted Platform Module (TPM) for hardware-based encryption, and a lock slot for physical security.\nDesign: Lightweight and sleek, with a high screen-to-body ratio for more screen space.\n\nOperating System: DOS\nKeyboard: English & Arabic\nAdditional Features:\n\nSolid-State Storage: 256GB SSD for fast boot times and improved performance.\nHP Noise Cancellation: Enhances online call quality by filtering out unwanted noise.\n\n\nThis laptop combines portability, performance, and connectivity, making it a versatile choice for various computing needs.\n\xa0\n\xa0\n\xa0\n',
#  'The MEETION CP2020 Gaming Cooling Pad offers several features designed to enhance your gaming experience:\n\nFast Cooling and Low Noise: The cooling pad is engineered to cool your laptop quickly while operating quietly.\nLED Backlight Design: It comes with an LED backlight that adds a stylish touch and enhances the gaming atmosphere.\nAluminum Alloy Top: The upper cover is made from aluminum alloy, which helps dissipate heat effectively and prevents overheating during intense gaming sessions.\nAdjustable Height: The cooling pad features two levels of height adjustment to suit your ergonomic preferences.\nNon-Slip Foot Rest: The bottom design includes a foot rest to keep the laptop in place and prevent sliding.\nUSB Powered: It is powered via USB, which makes it easy to use with no additional drivers required.\nCompatibility: It supports laptops ranging from 9 to 14 inches.\n\nThis cooling pad is designed to enhance both the performance and comfort of your gaming setup.\n\xa0\n\xa0\n\xa0\n',
#  '\n\n\n\nThe MEETION CP3030 Gaming Cooling Pad:\n\nFast Cooling & Low Noise: Efficiently cools your laptop while minimizing noise.\nRGB Backlighting: Adds a vibrant, immersive atmosphere.\nAluminum Alloy Top: Enhances heat dissipation and prevents overheating.\nAdjustable Fan Speed: Customizable cooling performance.\nHeight Adjustable: Four levels of height adjustment for ergonomic use.\nFoot Rest Design: Prevents the laptop from sliding.\nUSB Power Supply: Plug-and-play with no drivers needed.\nCompatibility: Suitable for laptops from 9 to 15.6 inches.\n\n\n\n\n\n\xa0\n\xa0\n\xa0\n',
#  "The Meetion SP1001 Office Strip Desktop Speakers offer an impressive array of features, making them suitable for both office work and entertainment. Here's a summary of their key highlights:\n\n\nRGB Lighting Effect: These speakers feature customizable RGB lighting, adding a dynamic visual effect to your setup.\n\n\nEasy-Access Control: The speakers come with convenient controls, allowing users to adjust volume or settings effortlessly.\n\n\nFull-Range Speaker with Inverted Hole Design: Designed to deliver clear high-pitched tones and deep bass, these speakers ensure a balanced audio experience.\n\n\nPro Audio Driver Units: These provide rich, immersive audio, ideal for music, videos, and even gaming.\n\n\nPlug and Play: The speakers offer simple plug-and-play functionality, ensuring easy setup without the need for additional software or drivers.\n\n\nWide Compatibility: They work with any device featuring a standard 3.5mm headphone jack, making them versatile for use with computers, laptops, tablets, and smartphones.\n\n\n\xa0\n\xa0\n\xa0\n",
#  'It looks like you’re detailing the features of the Gaming Stereo Desktop Speakers. Here’s a summarized version based on your points:\n\n\nHigh-Fidelity Sound Quality: The speakers offer high-fidelity output, with a dual-speaker design (left and right) that produces rich stereo sound.\n\n\nSmart Crossover Technology: This feature helps restore music’s true essence by ensuring balanced and accurate sound reproduction.\n\n\nCool Lighting Effects: They come with vivid LED lighting that adds a dynamic visual element to your setup.\n\n\nWide Compatibility: The speakers are compatible with any device that has a standard 3.5mm headphone jack, making them versatile for different devices.\n\n\nMini LED Laptop Speakers: They’re compact, making them suitable for use with laptops and other devices with limited space.\n\n\n',
#  'Processor and Performance:\n\nProcessor: 13th Generation Intel® Core™ i7-1355U with 10 cores and 12 threads, offering up to 5.0 GHz via Intel® Turbo Boost Technology. Ideal for multitasking and demanding applications.\nGraphics: It comes with both Integrated Intel® UHD Graphics and Discrete NVIDIA® GeForce RTX™ 2050 Laptop GPU (4 GB GDDR6), providing good performance for graphical applications and moderate gaming.\n\nMemory and Storage:\n\nRAM: 8 GB DDR4-3200 MHz (1 x 8 GB) with two SODIMM slots, allowing for future upgrades.\nStorage: 512 GB PCIe® NVMe™ SSD, offering fast storage and quick boot times.\n\nDisplay:\n\nScreen: 15.6″ diagonal Full HD (1920 x 1080) IPS panel with narrow bezels, anti-glare coating, 250 nits brightness, and 45% NTSC color gamut. This is a good quality display for most business tasks, though not ideal for color-critical work like photo editing.\n\nBattery and Build:\n\nBattery: 51 Wh 3-cell Li-ion battery, which is not replaceable by the customer, offering decent battery life for regular workday use.\nBuild: Light and portable, weighing 1.79 kg with a slim aluminum design.\n\nConnectivity:\n\nPorts:\r\n\r\n\t\n2 USB Type-A\n2 USB Type-C (supporting power delivery and DisplayPort 2.1)\n1 HDMI 2.1\n1 RJ-45 Ethernet\n1 stereo headphone/microphone combo jack.\n\n\nWireless: Intel® Wi-Fi 6E and Bluetooth® 5.3 ensure fast and stable wireless connectivity.\n\nAdditional Features:\n\nSecurity: Includes advanced security features like TPM 2.0, HP Sure Start Gen7, fingerprint sensor, and various other security management tools.\nSustainability: Made with sustainable materials and packaging.\n\n\xa0\n\xa0\n\xa0\n',
#  'Lenovo LOQ 83DV00JYIN is a powerful gaming and performance laptop with the following key specifications:\n\nProcessor: Intel Core i7-13650HX, a high-performance processor designed for gaming and demanding applications.\nGraphics Card: NVIDIA RTX 3050 with 6GB VRAM, providing solid gaming and graphical performance for a wide range of modern games.\nMemory: 16GB DDR5 RAM clocked at 4800MHz, ensuring fast and smooth multitasking.\nStorage: 1TB M.2 SSD, offering fast read/write speeds and ample storage space.\nDisplay: 15.6-inch Full HD (1920x1080) IPS display with 100% sRGB color accuracy and a 144Hz refresh rate, providing vibrant colors and smooth visuals, especially for gaming and creative tasks.\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n',
# ...
#  'Omen by HP 2019 15-Inch Gaming Laptop, Intel i7-9750H Processor, NVIDIA GTX 1650 4 GB, 16 GB RAM, 1T 256 GB SSD, VR Ready, Windows 10 Home\xa0\n',
#  '\n\nSades SA801 Over-Ear Stereo Gaming Headset with Microphone Noise Isolation for New Xbox One PC Mac Tablets PS4 Laptop Phone-Black Green\n\xa0\n\n\n\xa0\n',
#  "\n\n\nCan be used not only in PS4 and PC and 2015 Version Xbox One but also compatible with your daily used Phone, Laptop, Tablet, Notebook. Please note that you need extra Microsoft Adapter when connecting your first generation Xbox One controller.\nThe omnidirectional condenser microphone can catch every detailed speaking accurately when collecting sounds, it is much sensitive and the frequency response is much wide.\nCapture the flying bullets, footsteps and all effects in games easily and deliver a crisp rich and clear sound.\nComfortable ear cushions and unique 3-pieces of padded headband guarantee hours of gaming without fatigue.\nClosed earcups cover your entire ears and cut out external sound very effectively, and without the irritating 'seashell effect' many headsets suffer.\n\n\n\n",
#  '\n\nThis modern, transportable 15.6-inch laptop computer pushes gaming efficiency to a brand new stage. Its latest-generation specs assure you severe energy. Thermally optimized to run cooler and quieter with a full-sized white-backlit keyboard, the Lenovo Legion Y540 Laptop computer is primed for many who demand gaming wherever life takes them\n\n\n\n\n\n\n\xa0\n\n\n\n\n',
#  'Omen by HP 2019 15-Inch Gaming Laptop i7-9750H, 1660Ti 6 GB, 16 GB RAM,1T + 256 GB SSD, W10\xa0\n',
#  'LENOVO IDEAPAD S540 INTEL CORE I5-8265U 8GB DDR4 1TB+128GB SSD NVIDIA GTX1650 4GB\n',
#  '\nSC (single-level Cell) caching boosts write performance to quickly perform everyday tasks\nShock-resistant and WD F. I. To lab certified for compatibility and reliability\nUltra low power-draw so you can use your laptop PC for longer periods of time\nAvailable in 2. 5”/7mm cased and M. 2 2280 form factors to accommodate most PCs\n\n\xa0\n\xa0\n\xa0\n',
#  'HP 15-da1018ne Laptop - Intel Core i5 - 8GB RAM - 1TB HDD - 15.6-inch HD - 4GB GPU - DOS\xa0\n',
#  '\n\nRedragon K561 VISNU Mechanical Gaming Keyboard, Anti-ghosting 87 Keys, RAINBOW LIGHT, Wired Compact Keyboard with Clicky Blue Switches for Laptop, Windows, PC Games\n\xa0\n\n\n\xa0\n',
#  'Intel® Core I3-7020U 3M Cache 2.30 GHz\nIntel HD Graphics 620\n\xa0\n\xa015.6" Inch HD\n1T Hard Drive\n4 GB Memory\xa0\n',
#  '8th Generation Intel® Core™ i7-8565U\xa0\nNVIDIA® GeForce® MX 230 2GB GDDR5\n15.6" HD (1366x768)\n1TB Hard Drive\n8GB 2400MHz DDR4\xa0\n',
#  '8th Generation Intel® Core™ i5-8265U Processor\nNVIDIA® GeForce® MX 110 2GB GDDR5\n\xa015.6" HD (1366x768)\n1TB Hard Drive\n4GB 2400MHz DDR4\xa0\n',
#  '\nCrystal clear sound and excellent noise isolation brings you a total immersion into your gaming session; The 40mm neodymium directional drivers with 103dB sensitivity deliver extreme audio precision, while the soft padded Closed ear cups offer advanced passive noise isolation\nThe headset offers ultimate comfort for prolonged gaming sessions through its low weight and noise reducing closed ear cups using soft comfortable signature memory foam with highly adjustable headband for perfect fit\nHighly adjustable noise cancelling microphone; the highly adjustable microphone offers optimized noise and echo cancelling technology for your voice chat during gaming sessions\nHigh quality cable with smart in-line volume control, the 6 foot long high quality cable comes with a gold plated 3.5mm connector and smart in-line volume controller which offers convenient and precise volume control\nIncluded is a 2 x 3.5mm to 1 x 3.5mm adapter ensuring complete compatibility to support all your devices such as PC, Laptop, Mobile, Console and more.\n\xa0\n\n',
#  '\n\nThis modern, transportable 15.6-inch laptop computer pushes gaming efficiency to a brand new stage. Its latest-generation specs assure you severe energy. Thermally optimized to run cooler and quieter with a full-sized white-backlit keyboard, the Lenovo Legion Y540 Laptop computer is primed for many who demand gaming wherever life takes them\n\n\n\n\n\n\n\xa0\n\n\n\n\n',
#  '\n\nThis modern, transportable 15.6-inch laptop computer pushes gaming efficiency to a brand new stage. Its latest-generation specs assure you severe energy. Thermally optimized to run cooler and quieter with a full-sized white-backlit keyboard, the Lenovo Legion Y540 Laptop computer is primed for many who demand gaming wherever life takes them\n\n\n',
#  '\nIntel Core i7-8750H, 2.2 GHz CPU\n8GB RAM,128GB SSD + 1TB HDD\n15.6-inch FHD IPS LED-Backlit Screen\n4GB NVIDIA GeForce GTX 1050 GPU\nWi-Fi 802.11ac, Bluetooth 5.0\n2 x USB 3.1, 1 x HDMI\n4-Cell Battery, OS: Windows 10\n\n',
#  '\n\nBearing Type:\xa0Hydro Bearing\nRated Voltage: 5VDC\nOperating Voltage:\xa04.5～5VDC\nStarted Voltage:\xa0\xa04VDC\nPower Input:\xa01~2W\nFan Speed:\xa01300±10%RPM\n\xa0\n\n\n',
#  'Lenovo IdeaPad 330 Gaming\xa0Laptop,i7-8750H,1050 4GB,1T,8RAM\n',
#  'This modern, transportable 15.6-inch laptop computer pushes gaming efficiency to a brand new stage. Its latest-generation specs assure you severe energy. Thermally optimized to run cooler and quieter with a full-sized white-backlit keyboard, the Lenovo Legion Y540 Laptop computer is primed for many who demand gaming wherever life takes them\n',
#  '\n\nThis modern, transportable 15.6-inch laptop computer pushes gaming efficiency to a brand new stage. Its latest-generation specs assure you severe energy. Thermally optimized to run cooler and quieter with a full-sized white-backlit keyboard, the Lenovo Legion Y540 Laptop computer is primed for many who demand gaming wherever life takes them\n\n\n',
#  'Lenovo Ideapad 330 Intel Core i7-8550U 8GB Ram 2TB HDD VGA Nvidia Geforce MX 150 4G That includes as much as FHD decision on a 15.6” show, the Ideapad 330 delivers highly effective visuals on the go\n\xa0\n',
#  'PERFORMANCE\nProcessor \nIntel Core i7-9750H (6C / 12T, 2.6 / 4.5GHz, 12MB)\nGraphics \nNVIDIA GeForce GTX 1650 4GB GDDR5\nChipset \nIntel HM370\nMemory \n8GB SO-DIMM DDR4-2400\nMemory Slots \nOne DDR4 SO-DIMM slot\nMax Memory \nUp to 16GB (16GB SO-DIMM) DDR4-2400 offering\nStorage \n256GB SSD M.2 2242 PCIe 3.0x2 NVMe + 1TB HDD 5400rpm 2.5"\nOptane Memory \nNone\nStorage Support \nUp to 2 drives, 1x 2.5" HDD + 1x M.2 2242/2280 SSD\n• 2.5" HDD up to 2TB\n• M.2 2242 SSD up to 512GB\n• M.2 2280 SSD up to 1TB\n• Optional Intel Optane Memory or Optane Memory integrated with SSD, M.2\n',
#  '\xa0\xa0The newest edition to the world’s best-selling* SATA SSD series, the Samsung 860 EVO. Specially designed for mainstream PCs and laptops, with the latest V-NAND and a robust algorithm-based controller, this fast and reliable SSD comes in a wide range of compatible form factors and capacities.\n',
#  'Simplicity Meets Performance\n\nSlim and Lightweight for Portable Cooling\r\nTake the stand wherever you want, and use it whenever you need.\nSilent Plug-and-Play Fan\r\nOne large fan (160mm), instead of multiple smaller fans to reduce noise and efficiently dissipate heat in silence.\nFull Mesh Metal Board\r\nFull range frameless mesh allows superior airflow and prevents laptop slippage.\nErgonomic Comfort\r\nWith ergonomically proven 8 ° viewing angle, improve typing comfort and boost your productivity in the workplace and in the game.\n\n',
#  "Crucial® BX500 SSD Accelerate Everything\r\n\xa0Ever wonder why your phone responds faster than your computer? It's because your phone runs on flash memory. Add flash to your laptop or desktop computer with the Crucial® BX500 SSD, the easiest way to get all the speed of a new computer without the price. Accelerate everything.\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n",
#  'VERSATILE COMPATIBILITY: Compatibles with PC Windows XP, Win10,Win 7, Win8, Mac, etc., and mobile/tablet devices with a USB 2.0 connection. The professional gaming headset also is suitable for PC and laptop. The gaming headset has high sensitive Microphone and driver-free suitable for all audio devices with USB port.\nSURROUND SOUND: Equipped with High Performance 7.1 Audio and intelligent extreme bass enhances sound clarity and provides you studio sound field and makes it valuable for various games.\nCRYSTAL CLEAR CHAT: High quality ear cushions reduces background noise. A 360 degree sound sources absorbed hidden microphone picks-up your voice loud and clear. Perfect for in-game and online chat, and then remove it when watching movies or listening to music.\nLIGHTWEIGHT & COMFORTABLE: Premium super cushiony pads and adjustable ergonomically designed headband make the headphones comfortable for long time wear especially for the people who love playing PC game. Redragon devotes to deliver best gaming experiencing to player.\nPLUG & PLAY: Not need to setup or installation. The headphone is packaged ready for instant use and enjoyment.\n',
#  'Noise cancellation\nCompatible with: Laptop, gaming console, tablet, mobile\nDesign: Over the head\nSweat proof\nDeep bass\nGaming rgb color\nVolume control, reset\nNoise reduction: 20 db, Headphone Jack: 3.5\nSensitivity: 103 dbmw, impedance: 32 ohm, minimum frequency response: 20 Hz, maximum frequency response: 20000 Hz\nPlay time: 20 hr, buttons number:-3, detachable microphone, perfect gaming head\n',
#  'Mouse Type: Optical Mouse\nConnectivity: USB\nCompatible with: PC & Laptop\n',
#  '\nMouse Type: Optical Mouse\nConnectivity: USB\nCompatible with: PC & Laptop\n\n',
#  'Brand: Rapoo\nPlatform: PC\nMac compatibility: No\nMouse Type: Optical Mouse\nConnectivity: USB\nCompatible with: PC & Laptop\n\xa0\n',
#  'Rapoo 1620 2.4G Wireless Optical Mouse 1000DPI For Notebook Laptop & PC\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n',
#  'Mouse Type : Optical Mouse\nConnectivity : USB\nCompatible with : PC & Laptop\nModel Number : M606\nAre batteries needed to power the product or is this product a battery : No\nIs this a Dangerous Good or a Hazardous Material, Substance or Waste that is regulated for transportation, storage, and/or disposal? : No\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n',
#  '\nIntel Core i7-8750H, 2.2 GHz CPU\n16GB RAM,128GB SSD + 1TB HDD\n15.6-inch FHD IPS LED-Backlit Screen\n4GB NVIDIA GeForce GTX 1050 \xa0GPU\nWi-Fi 802.11ac, Bluetooth 5.0\n2 x USB 3.1, 1 x HDMI\n4-Cell Battery, OS: WINDOWS 10\n\n',
#  '2.5-inch\nSATA 3.0\nRead speed up to 560 MB\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n',
#  '\n\xa0\n\nIntel Core i7-8750H, 2.2 GHz CPU\n16GB DDR4 RAM, 1TB HDD + 128GB M.2 SSD\n15.6-inch Full HD IPS Anti-Glare Screen\n4GB NVIDIA GeForce GTX 1050 Ti GPU\nWi-Fi 802.11 a/c, Bluetooth 4.1\n1 x USB 3.1 (Type-C), 3 x USB 3.1, Mini DisplayPort, HDMI\n3-cell Battery, OS: DOS\n\n\n\xa0\n',
#  '\n\xa0\n\nIntel Core i3-7020U, 2.30 GHz CPU\n4GB DDR4 RAM, 1TB HDD\n15.6-inch FHD Anti-Glare Screen\n2GB AMD Radeon 530 GPU\nWi-Fi 802.11 b/g/n/ac, Bluetooth 4.1\n2 x USB 3.0, 1 x USB-Type C, HDMI\n2 Cell Battery, OS: DOS\n\n\n\n\n\xa0\n\nIntel Core i3-7020U, 2.30 GHz CPU\n4GB DDR4 RAM, 1TB HDD\n15.6-inch FHD Anti-Glare Screen\n2GB AMD Radeon 530 GPU\nWi-Fi 802.11 b/g/n/ac, Bluetooth 4.1\n2 x USB 3.0, 1 x USB-Type C, HDMI\n2 Cell Battery, OS: DOS\n\n\n\xa0\n\n',
#  '\nAMD A4-9125, 2.30 GHz CPU\n4GB DDR4 RAM, 1TB HDD\n15.6-inch HD Anti-Glare Screen\nAMD Radeon R3 GPU\nWi-Fi 802.11 b/g/n/ac, Bluetooth 4.1\n2 x USB 3.0, 1 x USB-Type C, HDMI\n2 Cell Battery, OS: DOS\n\n',
#  '\nIntel Core i7-8550U, 1.8 GHz CPU\n8GB DDR4 RAM, 1TB HDD\n15.6-inch HD Anti-Glare LED-backlit Screen\n2GB NVIDIA GeForce 930MX GPU\nWi-Fi 802.11a/b/g/n/ac, Bluetooth 4.2\n2 x USB 3.0, 1 x USB 3.1 Type-C, HDMI, VGA\n3-cell Battery, OS: FreeDOS 2.0\nFull-sized Backlit Keyboard with numeric keypad\n\xa0\n\n',
#  '\xa0\n\nIntel Core i5\u200e-8265U\u200e,\u200e 1.6 GHz CPU\n8GB DDR4 RAM\u200e,\u200e 1TB HDD\n15.6\u200e-inch HD Anti\u200e-Glare LED\u200e-backlit Screen\n2GB NVIDIA GeForce MX130 GPU\nWi\u200e-Fi 802.11a/b/g/n/ac\u200e,\u200e Bluetooth 5.0\n2 x USB 3.1\u200e,\u200e 1 x USB 2.0\u200e,\u200e 1 x USB 3.1 Type\u200e-C\u200e,\u200e HDMI\n3\u200e-cell Battery\u200e,\u200e OS\u200e:\u200e FreeDOS 3.0\nFull\u200e-sized Keyboard with numeric keypad\n\n',
#  '\xa0\n\nIntel Core i7\u200e-8565U\u200e,\u200e 1.8 GHz CPU\n8GB DDR4 RAM\u200e,\u200e 1TB HDD\n15.6\u200e-inch HD Anti\u200e-Glare LED\u200e-backlit Screen\n2GB NVIDIA GeForce MX130 GPU\nWi\u200e-Fi 802.11a/b/g/n/ac\u200e,\u200e Bluetooth 5.0\n2 x USB 3.1\u200e,\u200e 1 x USB 2.0\u200e,\u200e 1 x USB 3.1 Type\u200e-C\u200e,\u200e HDMI\n3\u200e-cell Battery\u200e,\u200e OS\u200e:\u200e FreeDOS 3.0\nFull\u200e-sized Keyboard with numeric keypad\n\n',
#  '\xa0\n\nIntel Core i3\u200e-7020U\u200e,\u200e 2.3 GHz CPU\n4GB DDR4 RAM\u200e,\u200e 1TB HDD\n15.6\u200e-inch HD WLED\u200e-backlit Screen\n2 GB NVIDIA GeForce MX110 GPU\nWi\u200e-Fi 802.11b/g/n/ac\u200e,\u200e Bluetooth 4.2\n1 x USB 2.0\u200e,\u200e 2 x USB 3.1\u200e,\u200e 1 x HDMI\n3\u200e-cell Battery\u200e,\u200e OS\u200e:\u200e FreeDOS 2.0\nFull\u200e-size Keyboard with Numeric Keypad\n\n',
#  '\nCapacity: 240GB\nInterface: SATA 6Gb/s\nForm Factor: 2.5-inch/7mm\nCompatible with most desktop and laptop PCs\n\n',
#  '\n\n\nDigital Storage Capacity\n1 TB\n\n\nHard Disk Interface\nSATA 6 GB/s\n\n\nConnectivity Technology\nSATA\n\n\nBrand Name\nWestern Digital\n\n\nSpecial Features\nCompact\n\n\nHard Disk Form Factor\n3.5 Inches\n\n\nHard Disk Description\nMechanical Hard Disk\n\n\nCompatible Devices\nLaptop & PC\n\n\nInstallation Type\nInternal Hard Drive\n\n\nColor\nBlue\n\n\n\n',
#  '\n1. Comfortable design with 16-million-colors breathing light.\n2. Professional,adjustable sound modes for a superior gaming audio experience.\n3. Hidden noise-cancelling microphones and crystal-clear voice\n4. Ultra-strong and durable materias.\n5. Noise-isolating over-ear design with soft and comfortable earcups.\n6. Lightweight design with headband suspension systerm for unrivaled comfort.Specification:Stype: illuminated Gaming HeadsetModel: Rapoo VPRO VH200Frequency range: 20-20000HzSensitivity: 103?3dB/mWCable length: 2m (approximately)Impedance: 1kHz/32OMic: 3.5mmPlug: 3.5mm plugDiameter: 50mmPackage included1x Game Headset\n\n',
#  '\n300Mbps wireless speed ideal for smooth HD video, voice streaming and online gaming\nMini-sized design for convenient portability with a reliable high performance\nSoftAP Mode ? Turn a wired internet connection to a PC or Laptop into a Wi-Fi hotspot\nEasily setup a secure wireless connection with one-touch WPS button\n\n ',
#  '\nModel Number : SGB-3040-KKMF1-AR\nBrand : Cooler Master\nConnectivity : USB\nCompatible with : PC & Laptop\nColor : Black\nKeyboard Language : English & Arabic\nBatteries Included? : No\n\xa0\nConnectivity\xa0: USB\n\n',
#  '\nIntel Core i7-7700HQ, 2.8 GHz CPU\n16GB RAM, 512GB SSD + 1TB HDD\n15.6" Full HD LED-Backlit Screen\n6GB NVIDIA GeForce GTX 1060 GPU\nWi-Fi 802.11ac, Bluetooth 4.2\n1 x Thunderbolt, 3 x USB 3.1, 1 x HDMI\n4-Cell Battery, OS: DOS\n\n',
#  '\nIntel Core i7-8750H, 2.2 GHz CPU\n8GB RAM,128GB SSD + 1TB HDD\n15.6-inch FHD IPS LED-Backlit Screen\n4GB NVIDIA GeForce GTX 1050 Ti GPU\nWi-Fi 802.11ac, Bluetooth 5.0\n2 x USB 3.1, 1 x HDMI\n4-Cell Battery, OS: Ubuntu\n\n',
#  '\nIntel Core i7-8750H, 2.2 GHz CPU\n16GB RAM, 256GB SSD + 1TB HDD\n15.6-inch FHD IPS LED-Backlit Screen\n4GB NVIDIA GeForce GTX 1050 Ti GPU\nWi-Fi 802.11ac, Bluetooth 5.0\n2 x USB 3.1, 1 x HDMI\n4-Cell Battery, OS: Ubuntu\n\n',
#  '\nBrand: Rapoo\nPlatform: PC\nMac compatibility: No\nMouse Type: Optical Mouse\nConnectivity: USB\nCompatible with: PC & Laptop\n\n',
#  '\n\nCapacity\r\n1 TB\r\nInterface\r\nSATA\r\nDimensions (L x W x H)\r\n3.94" x 2.75" x 0.28"\r\nForm Factor\r\n2.5 Inch\r\nDisk Speed (RPM)\r\n5400rpm\r\nRecording Technology\r\nSMR\n\n\n',
#  'Lenovo Ideapad 320 Laptop - Intel Core i5-8250U, 15.6 Inch FHD, 8GB, 2TB, AMD 4GB, DOS, Platinum Grey\n\xa0\n']

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv

response = req.get('https://www.sigma-computer.com/search?search=laptop&submit_search=&route=product%2Fsearch')

soup = bs(response.text, 'html.parser')

desc = soup.find_all('div', attrs={'class': 'product-layout col-lg-15 col-md-4 col-sm-6 col-xs-12'})

url_link = []
for i in range(len(desc)):
    url_link.append('https://www.sigma-computer.com/' + desc[i].find('a')['href'])

title = []
for i in range(len(desc)):
    title.append(desc[i].find('a')['title'])

price_new = []
for i in range(len(desc)):
    price_new.append(desc[i].find('span', attrs={'class': 'price-new'}).text)

price_old = []
for i in range(len(desc)):
    price_old.append(desc[i].find('span', attrs={'class': 'price-old'}).text)

descriptions = soup.find_all('div', {'class': 'description'})
strong = []
for i in range(len(descriptions)):
    strong_tag = descriptions[i].find('strong')
    if strong_tag:
        strong.append(strong_tag.text)
    else:
        strong.append(None)

header = ['URL', 'Title', 'Price New', 'Price Old', 'Strong Description']

with open('products.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(header) 
    for i in range(len(desc)):
        writer.writerow([url_link[i], title[i], price_new[i], price_old[i], strong[i]])

print("Data has been saved to 'products.csv'")
# Out:
# Data has been saved to 'products.csv'
